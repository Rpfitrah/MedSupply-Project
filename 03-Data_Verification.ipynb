# %%
import pandas as pd
import pandas as pd
from sqlalchemy import create_engine
# %load_ext sql

# %%
# Create a connection to the PostgreSQL database
engine=create_engine('postgresql+psycopg2://postgres:password@localhost:5432/medsupply')
connection=engine.connect()
print("Connected:", connection.closed == False)
# Out:
# Connected: True

# %%
# check connection using SQL magic command
# %sql postgresql+psycopg2://postgres:password@localhost:5432/medsupply
# Out:
# 'Connected: postgres@medsupply'

# %% [markdown]
# Check Column Name Length and Escaped Characters

# %%
# %%sql
# SELECT column_name,
#        length(column_name) AS len,
#        encode(column_name::bytea, 'escape') AS escaped
# FROM information_schema.columns
# WHERE table_name = 'customers'
# ORDER BY ordinal_position;
# Out:
#  * postgresql+psycopg2://postgres:***@localhost:5432/medsupply
# 6 rows affected.
# [('customer_id', 11, 'customer_id'),
#  ('customer_name', 13, 'customer_name'),
#  ('facility_type', 13, 'facility_type'),
#  ('pic_name', 8, 'pic_name'),
#  ('pic_phone', 9, 'pic_phone'),
#  ('total_transaction', 17, 'total_transaction')]

# %%
# %%sql
# SELECT column_name,
#        length(column_name) AS len,
#        encode(column_name::bytea, 'escape') AS escaped
# FROM information_schema.columns
# WHERE table_name = 'master_products'
# ORDER BY ordinal_position;
# Out:
#  * postgresql+psycopg2://postgres:***@localhost:5432/medsupply
# 6 rows affected.
# [('product_code', 12, 'product_code'),
#  ('product_name', 12, 'product_name'),
#  ('product_type', 12, 'product_type'),
#  ('stock_available', 15, 'stock_available'),
#  ('inden_lead_time_days', 20, 'inden_lead_time_days'),
#  ('supplier_cost', 13, 'supplier_cost')]

# %%
# %%sql
# SELECT column_name,
#        length(column_name) AS len,
#        encode(column_name::bytea, 'escape') AS escaped
# FROM information_schema.columns
# WHERE table_name = 'transactions_item'
# ORDER BY ordinal_position;
# Out:
#  * postgresql+psycopg2://postgres:***@localhost:5432/medsupply
# 10 rows affected.
# [('transaction_id', 14, 'transaction_id'),
#  ('product_type', 12, 'product_type'),
#  ('product_code', 12, 'product_code'),
#  ('product_name', 12, 'product_name'),
#  ('unit_price', 10, 'unit_price'),
#  ('quantity', 8, 'quantity'),
#  ('item_total', 10, 'item_total'),
#  ('inden_status', 12, 'inden_status'),
#  ('inden_flag', 10, 'inden_flag'),
#  ('inden_actual_time_days', 22, 'inden_actual_time_days')]

# %%
# %%sql
# SELECT column_name,
#        length(column_name) AS len,
#        encode(column_name::bytea, 'escape') AS escaped
# FROM information_schema.columns
# WHERE table_name = 'transactions_main'
# ORDER BY ordinal_position;
# Out:
#  * postgresql+psycopg2://postgres:***@localhost:5432/medsupply
# 6 rows affected.
# [('transaction_id', 14, 'transaction_id'),
#  ('customer_id', 11, 'customer_id'),
#  ('order_date', 10, 'order_date'),
#  ('delivery_date', 13, 'delivery_date'),
#  ('grand_total', 11, 'grand_total'),
#  ('invoice_status', 14, 'invoice_status')]

# %%
# %%sql
#
# SELECT *
# FROM customers
# LIMIT 5;
# Out:
#  * postgresql+psycopg2://postgres:***@localhost:5432/medsupply
# 5 rows affected.
# [('RS001', 'RS Permata', 'Hospital', 'Wadi Mangunsong', '+628265253065', 38),
#  ('RS002', 'RS Prastuti', 'Hospital', 'Ella Pertiwi', '+628831215727', 81),
#  ('RS003', 'RS Andriani', 'Hospital', 'Umi Pratama', '+628726589562', 90),
#  ('RS004', 'RS Dabukke', 'Hospital', 'Naradi Yulianti', '+628970241184', 95),
#  ('RS005', 'RS Budiyanto', 'Hospital', 'R.M. Cemani Rajasa', '+628327795791', 86)]

# %%
# %%sql
#
# SELECT *
# FROM master_products
# LIMIT 5;
# Out:
#  * postgresql+psycopg2://postgres:***@localhost:5432/medsupply
# 5 rows affected.
# [('MED-C001', 'Syringe 10ml', 'Consumable', 350, 0, Decimal('408471')),
#  ('MED-C002', 'N95 Mask', 'Consumable', 3963, 0, Decimal('153913')),
#  ('MED-C003', 'Catheter 16G', 'Consumable', 1924, 0, Decimal('144650')),
#  ('MED-C004', 'Nitrile Gloves L', 'Consumable', 4501, 0, Decimal('414766')),
#  ('MED-C005', 'Gauze 10x10cm', 'Consumable', 43, 0, Decimal('70739'))]

# %%
# %%sql
#
# SELECT *
# FROM transactions_item
# LIMIT 5;
# Out:
#  * postgresql+psycopg2://postgres:***@localhost:5432/medsupply
# 5 rows affected.
# [('TRX033', 'Device', 'MED-D109', 'Mindray Infusion Pump', Decimal('22922707'), 5, Decimal('114613535'), 'Yes (34 days)', 'Yes', 34),
#  ('TRX034', 'Device', 'MED-D102', 'Philips ECG PageWriter', Decimal('71397394'), 446, Decimal('31843237724'), 'No', 'No', None),
#  ('TRX035', 'Consumable', 'MED-C001', 'Syringe 10ml', Decimal('541546'), 280, Decimal('151632880'), 'No', 'No', None),
#  ('TRX036', 'Consumable', 'MED-C003', 'Catheter 16G', Decimal('407770'), 495, Decimal('201846150'), 'No', 'No', None),
#  ('TRX037', 'Device', 'MED-D108', 'GE Patient Monitor', Decimal('22296185'), 294, Decimal('6555078390'), 'Yes (22 days)', 'Yes', 22)]

# %%
# %%sql
#
# SELECT *
# FROM transactions_main
# LIMIT 5;
# Out:
#  * postgresql+psycopg2://postgres:***@localhost:5432/medsupply
# 5 rows affected.
# [('TRX001', 'CL019', datetime.date(2025, 12, 3), None, 29832856005.0, 'Customer Confirmation'),
#  ('TRX002', 'RS008', datetime.date(2025, 4, 16), datetime.date(2025, 4, 24), 10949452862.0, 'Completed'),
#  ('TRX003', 'RS018', datetime.date(2025, 1, 6), datetime.date(2025, 1, 28), 7924786476.0, 'None'),
#  ('TRX004', 'CL004', datetime.date(2025, 6, 13), None, 24791846.0, 'Customer Confirmation'),
#  ('TRX005', 'CL015', datetime.date(2025, 6, 11), datetime.date(2025, 6, 14), 10453248897.0, 'None')]

# %%
# %%sql
#
# SELECT
#     mp.product_code,
#     mp.product_name,
#     mp.inden_lead_time_days,
#     mp.stock_available,
#     ti.inden_actual_time_days
# FROM master_products as mp
# JOIN transactions_item as ti USING (product_code)
# WHERE ti.inden_flag = 'Yes'
# LIMIT 5;
# Out:
#  * postgresql+psycopg2://postgres:***@localhost:5432/medsupply
# 5 rows affected.
# [('MED-D109', 'Mindray Infusion Pump', 30, 0, 34),
#  ('MED-D108', 'GE Patient Monitor', 21, 0, 22),
#  ('MED-D118', 'Hillrom Hospital Bed', 14, 0, 14),
#  ('MED-D111', 'Olympus Endoscope', 21, 0, 19),
#  ('MED-D101', 'GE Logiq Ultrasound', 7, 0, 12)]

# %% [markdown]
# ### Missing value Percentage

# %%
# %%sql
#
# SELECT
#     COUNT(*) AS total_rows,
#     COUNT(*) - COUNT(stock_available) AS missing_count,
#     ROUND(((COUNT(*) - COUNT(stock_available)) * 100.0 / COUNT(*))::NUMERIC, 2) AS missing_percentage
# FROM master_products;
# Out:
#  * postgresql+psycopg2://postgres:***@localhost:5432/medsupply
# 1 rows affected.
# [(50, 10, Decimal('20.00'))]

# %%
# %%sql
#
# SELECT
#     COUNT(*) AS total_rows,
#     COUNT(*) - COUNT(unit_price) AS missing_count,
#     ROUND(((COUNT(*) - COUNT(unit_price)) * 100.0 / COUNT(*))::NUMERIC, 2) AS missing_percentage
# FROM transactions_item;
# Out:
#  * postgresql+psycopg2://postgres:***@localhost:5432/medsupply
# 1 rows affected.
# [(350, 17, Decimal('4.86'))]

# %%
# %%sql
#
# SELECT
#     COUNT(*) AS total_rows,
#     COUNT(*) - COUNT(quantity) AS missing_count,
#     ROUND(((COUNT(*) - COUNT(quantity)) * 100.0 / COUNT(*))::NUMERIC, 2) AS missing_percentage
# FROM transactions_item;
# Out:
#  * postgresql+psycopg2://postgres:***@localhost:5432/medsupply
# 1 rows affected.
# [(350, 17, Decimal('4.86'))]

# %%
# %%sql
#
# SELECT
#     COUNT(*) AS total_rows,
#     COUNT(*) - COUNT(item_total) AS missing_count,
#     ROUND(((COUNT(*) - COUNT(item_total)) * 100.0 / COUNT(*))::NUMERIC, 2) AS missing_percentage
# FROM transactions_item;
# Out:
#  * postgresql+psycopg2://postgres:***@localhost:5432/medsupply
# 1 rows affected.
# [(350, 17, Decimal('4.86'))]

# %%
# %%sql
#
# SELECT
#     COUNT(*) AS total_rows,
#     COUNT(*) - COUNT(inden_flag) AS missing_count,
#     ROUND(((COUNT(*) - COUNT(inden_flag)) * 100.0 / COUNT(*))::NUMERIC, 2) AS missing_percentage
# FROM transactions_item;
# Out:
#  * postgresql+psycopg2://postgres:***@localhost:5432/medsupply
# 1 rows affected.
# [(350, 17, Decimal('4.86'))]

# %%
# %%sql
#
# SELECT
#     COUNT(*) AS total_rows,
#     COUNT(*) - COUNT(inden_actual_time_days) AS missing_count,
#     ROUND(((COUNT(*) - COUNT(inden_actual_time_days)) * 100.0 / COUNT(*))::NUMERIC, 2) AS missing_percentage
# FROM transactions_item;
# Out:
#  * postgresql+psycopg2://postgres:***@localhost:5432/medsupply
# 1 rows affected.
# [(350, 296, Decimal('84.57'))]

# %%
# %%sql
#
# SELECT
#     COUNT(*) AS total_rows,
#     COUNT(*) - COUNT(inden_actual_time_days) AS missing_count,
#     ROUND(((COUNT(*) - COUNT(inden_actual_time_days)) * 100.0 / COUNT(*))::NUMERIC, 2) AS missing_percentage
# FROM transactions_item
# WHERE inden_flag = 'No';
# Out:
#  * postgresql+psycopg2://postgres:***@localhost:5432/medsupply
# 1 rows affected.
# [(279, 279, Decimal('100.00'))]

# %%
# %%sql
#
# SELECT
#     COUNT(*) AS total_rows,
#     COUNT(*) - COUNT(inden_actual_time_days) AS missing_count,
#     ROUND(((COUNT(*) - COUNT(inden_actual_time_days)) * 100.0 / COUNT(*))::NUMERIC, 2) AS missing_percentage
# FROM transactions_item
# WHERE inden_flag = 'Yes';
# Out:
#  * postgresql+psycopg2://postgres:***@localhost:5432/medsupply
# 1 rows affected.
# [(54, 0, Decimal('0.00'))]

# %%
# %%sql
#
# SELECT
#     COUNT(*) AS total_rows,
#     COUNT(*) - COUNT(delivery_date) AS missing_count,
#     ROUND(((COUNT(*) - COUNT(delivery_date)) * 100.0 / COUNT(*))::NUMERIC, 2) AS missing_percentage
# FROM transactions_main;
# Out:
#  * postgresql+psycopg2://postgres:***@localhost:5432/medsupply
# 1 rows affected.
# [(100, 54, Decimal('54.00'))]

# %%
# %%sql
#
# SELECT
#     COUNT(*) AS total_rows,
#     COUNT(*) - COUNT(grand_total) AS missing_count,
#     ROUND(((COUNT(*) - COUNT(grand_total)) * 100.0 / COUNT(*))::NUMERIC, 2) AS missing_percentage
# FROM transactions_main;
# Out:
#  * postgresql+psycopg2://postgres:***@localhost:5432/medsupply
# 1 rows affected.
# [(100, 5, Decimal('5.00'))]

# %%
# %%sql
#
# SELECT
#     COUNT(*) AS total_rows,
#     COUNT(*) - COUNT(invoice_status) AS missing_count,
#     ROUND(((COUNT(*) - COUNT(invoice_status)) * 100.0 / COUNT(*))::NUMERIC, 2) AS missing_percentage
# FROM transactions_main;
# Out:
#  * postgresql+psycopg2://postgres:***@localhost:5432/medsupply
# 1 rows affected.
# [(100, 5, Decimal('5.00'))]

# %% [markdown]
# Status unik dari invoice_status

# %%
# %%sql
#
# SELECT
#     DISTINCT invoice_status as unique_status,
#     COUNT(*) AS unique_count
# FROM transactions_main
# GROUP BY invoice_status;
# Out:
#  * postgresql+psycopg2://postgres:***@localhost:5432/medsupply
# 7 rows affected.
# [('Sent to Tax', 7),
#  ('Cancelled', 4),
#  ('Customer Confirmation', 46),
#  (None, 5),
#  ('None', 11),
#  ('Awaiting DN Signed', 8),
#  ('Completed', 19)]
